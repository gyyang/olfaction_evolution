# %%
# %pwd

# %%
# %cd C:\Users\Peter\PycharmProjects\olfaction_evolution

# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
import tools
from pylab import *
import matplotlib.animation as animation
import matplotlib as mpl
import numpy as np
import os
import standard.analysis as sa
import tools
import matplotlib.pyplot as plt
import task
import tensorflow as tf
from model import FullModel
from dict_methods import *

# %matplotlib inline
# Out:
# C:\Users\Peter\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
mpl.rcParams['font.size'] = 15
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.family'] = 'arial'
mpl.rcParams['image.cmap']='jet'

# %%
path = 'files/cluster_separate_lr50/'
x = tools.load_all_results(path, argLast=True)
# Out:
# ['files/cluster_separate_lr50/000000', 'files/cluster_separate_lr50/000001', 'files/cluster_separate_lr50/000002', 'files/cluster_separate_lr50/000003', 'files/cluster_separate_lr50/000004', 'files/cluster_separate_lr50/000005']

# %%
x.keys()
# Out:
# dict_keys(['w_bins', 'w_bins_log', 'lin_bins', 'epoch', 'train_loss', 'train_acc', 'lr_now', 'val_loss', 'val_acc', 'val_acc2', 'coding_level', 'coding_level_per_kc', 'coding_level_per_odor', 'log_hist', 'hist', 'kc_w_sum', 'lin_hist', 'sparsity', 'thres', 'sparsity_fixthres', 'K', 'bad_KC', 'NOISE_MODEL', 'N_CLASS', 'N_KC', 'N_ORN', 'N_ORN_DUPLICATION', 'N_PN', 'ORN_NOISE_STD', 'batch_size', 'coding_level_set', 'combinatorial_density', 'data_dir', 'dataset', 'decay_rate', 'decay_steps', 'direct_glo', 'distort_input', 'extra_layer', 'extra_layer_neurons', 'hallem_path', 'has_special_odors', 'initial_pn2kc', 'initializer_or2orn', 'initializer_orn2pn', 'initializer_pn2kc', 'kc_bias', 'kc_dropout', 'kc_dropout_rate', 'kc_inputs', 'kc_loss', 'kc_loss_alpha', 'kc_loss_beta', 'kc_noise', 'kc_noise_std', 'kc_norm_post', 'kc_norm_pre', 'kc_prune_threshold', 'kc_prune_weak_weights', 'label_type', 'lr', 'mask_orn_activation_column', 'mask_orn_activation_row', 'max_epoch', 'mean_subtract_pn2kc', 'model', 'n_class_valence', 'n_combinatorial_classes', 'n_proto_valence', 'n_train', 'n_trueclass', 'n_val', 'or2orn_normalization', 'or_bias', 'oracle_scale', 'orn_dropout', 'orn_dropout_rate', 'orn_norm', 'output_bias', 'path', 'percent_generalization', 'pn2kc_noise', 'pn2kc_noise_value', 'pn_dropout', 'pn_dropout_rate', 'pn_norm_post', 'pn_norm_pre', 'receptor_layer', 'relabel', 'replicate_orn_with_tiling', 'save_epoch_interval', 'save_every_epoch', 'save_log_only', 'save_path', 'separate_lr', 'separate_optimizer', 'set_oracle', 'shuffle_label', 'sign_constraint_or2orn', 'sign_constraint_orn2pn', 'sign_constraint_pn2kc', 'skip_orn2pn', 'skip_pn2kc', 'sparse_pn2kc', 'spread_orn_activity', 'target_acc', 'train_head1', 'train_head2', 'train_kc_bias', 'train_orn2pn', 'train_pn2kc', 'uniform_pn2kc', 'update', 'vary_concentration', 'log_val_loss', 'log_train_loss'])

# %%
w_bins_log = np.linspace(-20, 5, 200)

# %%
fig, axs =plt.subplots(6,figsize=(8,12))
for i in range(x['log_hist'].shape[0]):
    axs[i].plot(w_bins_log,x['log_hist'][i].T)
    axs[i].set_ylabel('lr = {}'.format(x['lr'][i]))

# %%
fig, axs =plt.subplots(6,figsize=(8,12))
lin_bins = np.linspace(0, 1, 200)
for i in range(x['log_hist'].shape[0]):
    axs[i].plot(lin_bins,x['hist'][i].T)
    plt.sca(axs[i])
    plt.ylim([0, 2000])
    plt.ylabel('lr = {}'.format(x['lr'][i]))

# %%
x.keys()
# Out:
# dict_keys(['w_bins', 'w_bins_log', 'lin_bins', 'epoch', 'train_loss', 'train_acc', 'lr_now', 'val_loss', 'val_acc', 'val_acc2', 'coding_level', 'coding_level_per_kc', 'coding_level_per_odor', 'log_hist', 'hist', 'kc_w_sum', 'lin_hist', 'sparsity', 'thres', 'sparsity_fixthres', 'K', 'bad_KC', 'NOISE_MODEL', 'N_CLASS', 'N_KC', 'N_ORN', 'N_ORN_DUPLICATION', 'N_PN', 'ORN_NOISE_STD', 'batch_size', 'coding_level_set', 'combinatorial_density', 'data_dir', 'dataset', 'decay_rate', 'decay_steps', 'direct_glo', 'distort_input', 'extra_layer', 'extra_layer_neurons', 'hallem_path', 'has_special_odors', 'initial_pn2kc', 'initializer_or2orn', 'initializer_orn2pn', 'initializer_pn2kc', 'kc_bias', 'kc_dropout', 'kc_dropout_rate', 'kc_inputs', 'kc_loss', 'kc_loss_alpha', 'kc_loss_beta', 'kc_noise', 'kc_noise_std', 'kc_norm_post', 'kc_norm_pre', 'kc_prune_threshold', 'kc_prune_weak_weights', 'label_type', 'lr', 'mask_orn_activation_column', 'mask_orn_activation_row', 'max_epoch', 'mean_subtract_pn2kc', 'model', 'n_class_valence', 'n_combinatorial_classes', 'n_proto_valence', 'n_train', 'n_trueclass', 'n_val', 'or2orn_normalization', 'or_bias', 'oracle_scale', 'orn_dropout', 'orn_dropout_rate', 'orn_norm', 'output_bias', 'path', 'percent_generalization', 'pn2kc_noise', 'pn2kc_noise_value', 'pn_dropout', 'pn_dropout_rate', 'pn_norm_post', 'pn_norm_pre', 'receptor_layer', 'relabel', 'replicate_orn_with_tiling', 'save_epoch_interval', 'save_every_epoch', 'save_log_only', 'save_path', 'separate_lr', 'separate_optimizer', 'set_oracle', 'shuffle_label', 'sign_constraint_or2orn', 'sign_constraint_orn2pn', 'sign_constraint_pn2kc', 'skip_orn2pn', 'skip_pn2kc', 'sparse_pn2kc', 'spread_orn_activity', 'target_acc', 'train_head1', 'train_head2', 'train_kc_bias', 'train_orn2pn', 'train_pn2kc', 'uniform_pn2kc', 'update', 'vary_concentration', 'log_val_loss', 'log_train_loss'])

# %%
x['coding_level']
# Out:
# array([0.61266582, 0.61481323, 0.61105322, 0.61463174, 0.61399634,
#        0.61102837])

# %%
x['train_acc']
# Out:
# array([0.765625  , 0.875     , 0.7890625 , 0.8203125 , 0.88671875,
#        0.84375   ], dtype=float32)

# %%
x['sparsity'].mean(axis=1)
# Out:
# array([9.6276, 9.6988, 9.6936, 9.6424, 9.5956, 9.6916])

# %%
x['thres']
# Out:
# array([0.18314471, 0.17859061, 0.17951663, 0.18122865, 0.18508987,
#        0.17821517])

# %%
x['lr']
# Out:
# array([3.e-03, 1.e-03, 3.e-04, 1.e-04, 3.e-05, 1.e-05])

# %%
plt.plot(np.log(x['lr']), x['sparsity'].mean(axis=1), '*')
plt.xticks(np.log(x['lr']),x['lr'])
plt.xlabel('LR')
plt.ylabel('Sparsity')
# Out:
# Text(0,0.5,'Sparsity')

# %%
plt.plot(np.log(x['lr']), x['train_acc'], '*')
plt.xticks(np.log(x['lr']),x['lr'])
plt.xlabel('LR')
plt.ylabel('Train Accuracy')
# Out:
# Text(0,0.5,'Train Accuracy')

# %%
plt.plot(np.log(x['lr']), x['thres'], '*')
plt.xticks(np.log(x['lr']),x['lr'])
plt.xlabel('LR')
plt.ylabel('Threshold')
# Out:
# Text(0,0.5,'Threshold')

# %%
plt.plot(np.log(x['lr']), x['coding_level'], '*')
plt.xticks(np.log(x['lr']),x['lr'])
plt.xlabel('threshold')
plt.ylabel('coding level')
# Out:
# Text(0,0.5,'coding level')

# %%
w_glo = tools.load_pickle(path, 'w_glo')[0]

# %%
log = tools.load_all_results(path, argLast=False)
# Out:
# ['files/cluster_separate_lr50/000000', 'files/cluster_separate_lr50/000001', 'files/cluster_separate_lr50/000002', 'files/cluster_separate_lr50/000003', 'files/cluster_separate_lr50/000004', 'files/cluster_separate_lr50/000005']
# C:\Users\Peter\PycharmProjects\olfaction_evolution\tools.py:226: RuntimeWarning: divide by zero encountered in log
#   res['log_train_loss'] = np.log(res['train_loss'])

# %%
from matplotlib import cm

start = 0.0
stop = 1.0
number_of_lines= sp.shape[0]
cm_subsection = np.linspace(start, stop, number_of_lines) 

colors = [ cm.cool(x) for x in cm_subsection ]

# %%
data = sp[1:,:]
legend = log['lr'][1:]

# %%
for i, d in enumerate(data):
    plt.plot(d, color=colors[i])
plt.legend(legend)
plt.ylabel('Sparsity (K)')
plt.xlabel('Epoch')
# Out:
# Text(0.5,0,'Epoch')
